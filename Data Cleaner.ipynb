# %%
import pandas as pd
import numpy as np
import re

# %%
FILENAMEC = 'child_triple.txt'
FILENAMEP = 'parent_triple.txt'
FILENAMES = 'spouse_triple.txt'

# %%
def load_data(filename):
    
    # reading our data from the respective text files
    data = pd.read_csv(filename, delimiter="\t", header=None)
    
    # dropping columns that are empty
    data.dropna(axis = 1, inplace = True)
    
    # renaming our columns from 0, 2, and 4 to person1, relation, and person2
    data.rename(columns={0:'person1', 2:'relation', 4:'person2'}, inplace = True)
    
    return data

# %%
def check(dataframe):
    
    #checking the number of rows and columns in the dataset
    print(f'The data has {dataframe.shape[0]} rows and {dataframe.shape[1]} colums.')
    
    #checking number of unique entries in the respective columns
    unique1 = dataframe['person1'].unique()
    unique2 = dataframe['person2'].unique()
    print(f'There are {len(unique1)} unique values in Person1 column and {len(unique2)} unique values in Person2 column.')
    
    print(f'Number of empty rows in the respective columns are person1: {dataframe.isnull().sum()[0]}, relation: {dataframe.isnull().sum()[1]}, person2: {dataframe.isnull().sum()[2]}')

# %%
def merge_column(data_x, data_xy, data_y, col1='person1', col2='relation', col3='person2', diff=True):
    
    #create a new col named 'relation triplet' and assign it the value of all columns combined
    if diff:
        data_xy['relation triplet'] = data_x[col1].astype(str) + ' ' + data_xy[col2].astype(str) + ' ' + data_y[col3].astype(str)
    else:
        data_xy['relation triplet'] = data_xy[col1].astype(str) + ' ' + data_xy[col2].astype(str) + ' ' + data_xy[col3].astype(str)
    
    return data_xy

# %%
child_data = load_data(FILENAMEC)
child_data.head()
# Out:
#             person1 relation                  person2
# 0   Abraham Lincoln    child      Robert Todd Lincoln
# 1   Abraham Lincoln    child     Edward Baker Lincoln
# 2   Abraham Lincoln    child  William Wallace Lincoln
# 3   Abraham Lincoln    child              Tad Lincoln
# 4  Alfred Hitchcock    child       Patricia Hitchcock

# %% [markdown]
# **The structure of the Child text file is "Parent - Relation - Child".**

# %%
parent_data = load_data(FILENAMEP)
parent_data.head()
# Out:
#                person1 relation               person2
# 0     Andrei Tarkovsky   parent      Arseny Tarkovsky
# 1  Alexander the Great   parent  Philip II of Macedon
# 2  Alexander the Great   parent              Olympias
# 3               Attila   parent               Mundzuk
# 4           Alp Arslan   parent           Chaghri Beg

# %% [markdown]
# **The structure of the Parent text file is "Child - Relation - Parent".**

# %%
spouse_data = load_data(FILENAMES)
spouse_data.head()
# Out:
#             person1 relation                 person2
# 0   Abraham Lincoln   spouse       Mary Todd Lincoln
# 1        Allan Dwan   spouse  Pauline Bush (actress)
# 2  Andrei Tarkovsky   spouse              Irma Raush
# 3  Andrei Tarkovsky   spouse      Larisa Tarkovskaya
# 4   Albert Einstein   spouse            Mileva Marić

# %% [markdown]
# **The structure of the Spouse text file is "Spouse - Relation - Spouse".**
# #### Gender information is unknown in all three files.

# %%
print("Child text data")
check(child_data)
print("------------------------------------------------------------------------------------------------")
print("Parent text data")
check(parent_data)
print("------------------------------------------------------------------------------------------------")
print("Spouse text data")
check(spouse_data)
print("------------------------------------------------------------------------------------------------")
# Out:
# Child text data
# The data has 14139 rows and 3 colums.
# There are 10003 unique values in Person1 column and 12356 unique values in Person2 column.
# Number of empty rows in the respective columns are person1: 0, relation: 0, person2: 0
# ------------------------------------------------------------------------------------------------
# Parent text data
# The data has 27824 rows and 3 colums.
# There are 19172 unique values in Person1 column and 17971 unique values in Person2 column.
# Number of empty rows in the respective columns are person1: 0, relation: 0, person2: 0
# ------------------------------------------------------------------------------------------------
# Spouse text data
# The data has 34163 rows and 3 colums.
# There are 30223 unique values in Person1 column and 31475 unique values in Person2 column.
# Number of empty rows in the respective columns are person1: 0, relation: 0, person2: 0
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# #### We don't have any empty values in all three of our dataframes.

# %%
14139 + 27824 + 34163
# Out:
# 76126

# %%
10003 + 19172 + 30223
# Out:
# 59398

# %%
12356 + 17971 + 31475
# Out:
# 61802

# %% [markdown]
# There are **76,126** rows in our dataset. Approximately we have around **59,398** unique values in *'person1'* column and **61,802** unique values in *'person2'* column. This is a rough estimate for now. We will find out the actual number of unique values when we merge the three dataframes into one and the three columns of this dataframe into one column.

# %%
# just an example of how unclean the data is
spouse_info = spouse_data['person2'].tolist()
spouse_info
# Out:
# ['Mary Todd Lincoln',
#  'Pauline Bush (actress)',
#  'Irma Raush',
#  'Larisa Tarkovskaya',
#  'Mileva Marić',
#  'Elsa Löwenthal',
#  'Roxana',
#  'Stateira II',
#  'Parysatis II',
#  'Kreka',
#  'Ildico',
#  'Alma Reville',
#  'Mabel Hubbard',
#  'Yōko Yaguchi',
#  'Edna Mayne Hull',
#  'William King-Noel, 1st Earl of Lovelace',
#  'Archie Christie',
#  'Max Mallowan',
#  'Helene Bresslau Schweitzer',
#  'Harry Bresslau',
#  'Asandhimitra',
#  'Jane Mackenzie',
#  'Faustina the Elder',
#  'Clodia Pulchra',
#  'Scribonia',
#  'Livia',
#  'Abby May',
#  'Rose Edith Kelly',
#  'Bonnie MacBird',
#  'Dorothea of Denmark, Duchess of Prussia',
#  'Anna Marie of Brunswick-Lüneburg',
#  'Sophie of Winzenburg',
#  'Rabia Sultan',
#  'Emine Mihrişah Sultan',
#  'Rabia Şermi Sultan',
#  'Kösem Sultan',
#  'Mahfiruz Hatice Sultan',
#  'Philip II of France',
#  'Germanicus',
#  'Gnaeus Domitius Ahenobarbus (consul 32)',
#  'Gaius Sallustius Crispus Passienus',
#  'Claudius',
#  'Chlothsind',
#  'Rosamund (Gepid)',
#  'Joan of England, Queen of Scots',
#  'Marie de Coucy',
#  'Helena of Moscow',
#  'Charlotte Christine of Brunswick-Lüneburg',
#  'Margaret of England',
#  'Yolande de Dreux, Queen of Scots',
#  'Sallustia Orbiana',
#  'Irene Doukaina',
#  'Rachel Jackson',
#  'Draga Mašin',
#  'Cleopatra Thea',
#  'Eliza McCardle Johnson',
#  'Maria Feodorovna (Dagmar of Denmark)',
#  'Gertrude of Merania',
#  'Yolanda de Courtenay',
#  "Beatrice D'Este (Queen Consort of Hungary)",
#  'Qutaylah bint Abd-al-Uzza',
#  'Umm Ruman',
#  'Asma bint Umais',
#  'Eurydice I of Macedon',
#  'Urraca of León and Castile',
#  'Isabella of Coimbra',
#  'Joanna La Beltraneja',
#  'Mafalda of Savoy, Queen of Portugal',
#  'Mercedes of Orléans',
#  'Maria Christina of Austria',
#  'Victoria Eugenie of Battenberg',
#  'Maria of Castile',
#  'Urraca of Castile, Queen of Portugal',
#  'Maria Francisca of Savoy',
#  'Matilda II of Boulogne',
#  'Beatrice of Castile (1242–1303)',
#  'Ealhswith',
#  'Beatrice of Castile (1293–1359)',
#  'Eutharic',
#  "Teresa d'Entença",
#  'Eleanor of Castile (1307-1359)',
#  'Maria Shriver',
#  'Jaya Bachchan',
#  'Agnes of Courtenay',
#  'Maria Komnene, Queen of Jerusalem',
#  'Eschiva of Ibelin (died 1196)',
#  'Isabella I of Jerusalem',
#  'Louise Whitfield Carnegie',
#  'R. Kelly',
#  'Petronella Barker (actress born 1942)',
#  'Dilras Banu Begum',
#  'Olga Knipper',
#  'Ota, wife of Arnulf of Carinthia',
#  'Casimir III of Poland',
#  'Yelena Bonner',
#  'Ayşe Seniyeperver Sultan',
#  'Nakşidil Sultan',
#  'Dürrünev Kadın',
#  'Edadil Kadın',
#  'Hayranidil Kadın',
#  'Neşerek Kadınefendi',
#  'Gevheri Kadın',
#  'Hugh Parker Guiler',
#  'Rupert Pole',
#  'Princess Henrietta of Nassau-Weilburg',
#  'Michael Aris',
#  'Carl Sagan',
#  'Munírih Khánum',
#  'Hillary Clinton',
#  'Annulment',
#  'Kevin Federline',
#  'Princess Maria Carolina of Savoy',
#  'Maria Theresa of Austria (1767–1827)',
#  'Sidonie Podiebrad of Bohemia',
#  'Marie Eleonore of Cleves',
#  'Pernilla August',
#  'Roger Vadim',
#  'Jacques Charrier',
#  'Gunter Sachs',
#  'Po Beg',
#  'Agnetha Fältskog',
#  'Anni-Frid Lyngstad',
#  'Melinda Gates',
#  'Mary Anne Disraeli',
#  'Florence Balcombe',
#  'Deborah Read',
#  'Dixie Lee',
#  'Kathryn Crosby',
#  'Hazel Hawke',
#  "Blanche d'Alpuget",
#  'Bruce Paltrow',
#  'Anthony Perkins',
#  'Theodore Olson',
#  'Nancy Allen (actress)',
#  'Gale Anne Hurd',
#  'Eugène Manet',
#  'Devlet Hatun',
#  'Hafsa Hatun',
#  'Olivera Lazarević',
#  'Nigar Hatun',
#  'Şirin Hatun',
#  'Gülruh Hatun',
#  'Bülbül Hatun',
#  'Hüsnüşah Hatun',
#  'Gülbahar Hatun',
#  'Muhtereme Hatun',
#  'Prasutagus',
#  'Cynda Williams',
#  'Angelina Jolie',
#  '1983 Major League Baseball season',
#  'Brenda Benet',
#  'Mildred Harris',
#  'Lita Grey',
#  'Paulette Goddard',
#  "Oona O'Neill",
#  'Filipa Moniz Perestrelo',
#  'Kurt Cobain',
#  'Violet Attlee, Countess Attlee',
#  'Catherine Dickens',
#  'Joy Davidman',
#  'Cathy Tyson',
#  'Frances Tupper',
#  'Grace Coolidge',
#  'Plautia Urgulanilla',
#  'Aelia Paetina',
#  'Valeria Messalina',
#  'Agrippina the Younger',
#  'Constance Adams DeMille',
#  'Swanachild',
#  'Arthur Bell Nicholls',
#  'Junia Claudilla',
#  'Livia Orestilla',
#  'Lollia Paulina',
#  'Milonia Caesonia',
#  'Lynn Margulis',
#  'Linda Salzman Sagan',
#  'Ann Druyan',
#  'Arthur, Prince of Wales',
#  'Henry VIII of England',
#  'Mao Fumei',
#  'Yao Yecheng',
#  'Chen Jieru',
#  'Soong Mei-ling',
#  'Alma Powell',
#  'Susan Sarandon',
#  'Joanna Gleason',
#  'Jamie Lee Curtis',
#  'Minervina',
#  'Fausta',
#  'Aldona of Lithuania',
#  'Adelaide of Hesse',
#  'Christina Rokiczana',
#  'Hedwig of Sagan',
#  'Henrietta Maria of France',
#  'Jenny Lee Lindberg',
#  'Harrison Ford',
#  'Charlotte of Albret',
#  'Walter Fuller',
#  'Mona Maris',
#  'Alice Joyce',
#  'Henry Kuttner',
#  'Halo Meadows',
#  'Linda Arvidson',
#  'Tom Green',
#  'Mary Sweeney',
#  'Charlotte Small',
#  'Ceán Chaffin',
#  'Grammy Awards of 1996',
#  'Mamie Eisenhower',
#  'Zhuo Lin',
#  'George William Weidler',
#  'Martin Melcher',
#  'Lindsay Crouse',
#  'Rebecca Pidgeon',
#  'Bridget Fonda',
#  'Wendy Fulton',
#  'Michelle Kaufman',
#  'Catherine Wellesley, Duchess of Wellington',
#  'Domitia Longina',
#  'Prisca (empress)',
#  'Victoria Beckham',
#  'Toni Hudson',
#  'Rosario Murillo',
#  'Helen Palmer Geisel',
#  'Brooke Hayward',
#  'Michelle Phillips',
#  'Daria Halprin',
#  'Katherine LaNasa',
#  'Mieszko I of Poland',
#  'Caitlin Thomas',
#  'Phyllis Huffman',
#  'Elizaveta Svilova',
#  'Sylvia Fine',
#  'Priscilla Presley',
#  'Karin Stoiber',
#  'Nina Grieg',
#  'Virginia Eliza Clemm Poe',
#  'Suzanne Leenhoff',
#  'Otto I, Holy Roman Emperor',
#  'Bertha of Kent',
#  'Xerxes I',
#  'Louis VII of France',
#  'Henry II of England',
#  'Jimena Díaz',
#  'Fujiwara no Otomuro',
#  'Princess Sakahito',
#  'Alwine Dollfuß',
#  'Hugh Alexander Pollock',
#  'Nexhmije Hoxha',
#  'Laura Capon Fermi',
#  'Esther Marion Armstrong',
#  'Emperor Tenmu',
#  'Emperor Bidatsu',
#  'Ælfgifu of Shaftesbury',
#  'Æthelflæd of Damerham',
#  'Edwina Mountbatten, Countess Mountbatten of Burma',
#  'Ann Thompson Gerry',
#  'Tachibana no Kachiko',
#  'Rosina Bulwer Lytton',
#  'Princess Seishi',
#  'Jeff Dunas',
#  'Anne Jackson',
#  'Gail Zappa',
#  'Eleanor Coppola',
#  'Anna Murray-Douglass',
#  'Helen Pitts Douglass',
#  'Eleanor Roosevelt',
#  'Carola of Vasa',
#  'John Monk Saunders',
#  'Robert Riskin',
#  'Ava Gardner',
#  'Mia Farrow',
#  'Barbara Sinatra',
#  'Verena Huber-Dyson',
#  'Eleanor of Portugal, Holy Roman Empress',
#  'Carmen Polo, 1st Lady of Meirás',
#  'Odile Crick',
#  'Countess Luise Henriette of Nassau',
#  'Sophia Dorothea of Schleswig-Holstein-Sonderburg-Glücksburg',
#  'Marike de Klerk',
#  'Anna Grigoryevna Snitkina',
#  'Polissena Ruffo',
#  'Bianca Maria Visconti',
#  'Thea von Harbou',
#  'Duchess Elisabeth of Württemberg',
#  'Maria Theresa of Naples and Sicily',
#  'Maria Ludovika of Austria-Este',
#  'Caroline Augusta of Bavaria',
#  'Giulietta Masina',
#  'Sophia Dorothea of Hanover',
#  "Eileen O'Shaughnessy",
#  'Sonia Brownell',
#  'Archduchess Marie Caroline of Austria',
#  'Maria Anna of Bavaria (1805-1877)',
#  'Eva Nansen',
#  'Marcia Lucas',
#  'Mellody Hobson',
#  'Barbara Bush',
#  'Martha Washington',
#  'Sophia of Poland',
#  'Betsy Blair',
#  'Jeanne Coyne',
#  'Trisha Yearwood',
#  'Eva König',
#  'Frances Blogg',
#  'Jane Pauley',
#  'Eden Hartford',
#  'Agrippina the Elder',
#  'Margaret Whitlam',
#  'Frances Folsom Cleveland Preston',
#  'Elizabeth Ashley',
#  'Sherry Boucher',
#  'Philippa Roet',
#  'Elizabeth Charlotte of the Palatinate (1597-1660)',
#  'Anne Lockhart, Countess of Aberdeen',
#  'Charlotte Payne-Townshend',
#  'Athole Shearer',
#  'Slim Keith',
#  'Dee Hartford',
#  'Barbara Jagiellon',
#  'Majel Barrett',
#  'Elisabeth of Brandenburg-Küstrin',
#  'Sophie of Brunswick-Lüneburg',
#  'Beatrice de Frangepan',
#  'Hedwig of Münsterberg-Oels',
#  'Emilie of Saxony',
#  'Margaret Fell',
#  'Sarolt of Transylvania',
#  'Sarah Jane Brown',
#  'Ebba Witt-Brattström',
#  'Sonia Greene',
#  'Margarete Himmler',
#  'Lou Henry Hoover',
#  'David Justice',
#  '1993 in film',
#  '1997 in film',
#  'Eric Benét',
#  '2001 in film',
#  '2005 in film',
#  'Olivier Martinez',
#  '2013 in film',
#  'Nancy Kissinger',
#  'Zara Bate',
#  'Matilda of Ringelheim',
#  'Ellen Vesta Emery Hamlin',
#  'Helen Menken',
#  'Mary Philips',
#  'Mayo Methot',
#  'Lauren Bacall',
#  'Bega Begum',
#  'Jean Peters',
#  'Elizabeth of York',
#  'Matilda of Scotland',
#  'Adeliza of Louvain',
#  'Suzannah Thoresen',
#  'Kimberley Conrad',
#  'Crystal Harris',
#  'Margaret Alexander, Countess Alexander of Tunis',
#  'Mariusz Czerkawski',
#  'Janet Asimov',
#  'Mevhibe İnönü',
#  'Else Fisher',
#  'Käbi Laretei',
#  'Ingrid von Rosen',
#  'Coco Austin',
#  'Marion Ravenwood',
#  'Feroze Gandhi',
#  'Francesco II Gonzaga, Marquess of Mantua',
#  'Mary Hayward Weir',
#  'Elizabeth Batts Cook',
#  'Gale Anne Hurd',
#  'Kathryn Bigelow',
#  'Linda Hamilton',
#  'Suzy Amis',
#  'Ekaterina Svanidze',
#  'Nadezhda Alliluyeva',
#  'Louisa Adams',
#  'Frances McDormand',
#  'Tricia Cooke',
#  'Christina Rau',
#  'Tomi Rae Hynie',
#  'Magda Goebbels',
#  'Cynthia Stone',
#  'Felicia Farr',
#  'Norma Major',
#  'Edie Parker',
#  'Cornelia (wife of Caesar)',
#  'Pompeia (wife of Julius Caesar)',
#  'Calpurnia (wife of Caesar)',
#  'Marilyn Quayle',
#  'Isabella Macdonald',
#  'Agnes Macdonald, 1st Baroness Macdonald of Earnscliffe',
#  'Elizabeth Simcoe',
#  'Edna Brower',
#  'Olive Palmer',
#  'Edith Tolkien',
#  'Connie Booth',
#  'Barbara Trentham',
#  'Alyce Cleese',
#  'Susan Lynch (pediatrician)',
#  'Cynthia Lennon',
#  'Yoko Ono',
#  'Annie Thompson',
#  'Dolley Madison',
#  'Elizabeth Monroe',
#  'Katinka Kendeffy',
#  'Sarah Childress Polk',
#  'Rosalynn Carter',
#  'Kara Anastasio',
#  'Josephine Alicia Saenz',
#  'Esperanza Baur',
#  'Pilar Pallete',
#  'Sarah Knox Taylor',
#  'Varina Davis',
#  'Cris Judd',
#  'Marc Anthony',
#  'Marceline Loridan-Ivens',
#  'Tammy Faye Messner',
#  'Patricia Medina',
#  'Jane Henson',
#  'Simone Melchior Cousteau',
#  'Francine Triplet Cousteau',
#  'Gloria Hatrick McLean',
#  'Hayley Mills',
#  'Evans Evans',
#  'Dorothy Quincy',
#  'Elizabeth of Denmark, Norway, and Sweden',
#  'Paul Cushing Child',
#  'Władysław II Jagiełło',
#  'Huntington D. Sheldon',
#  'Kamla Nehru',
#  'Nur Jahan',
#  'Margaret of Thuringia',
#  'Sophie of Legnica',
#  'Sabina of Brandenburg-Ansbach',
#  'Elisabeth of Anhalt-Zerbst',
#  'Catherine of Brandenburg-Küstrin',
#  'Eleanor of Prussia',
#  'Anna, Duchess of Prussia',
#  'Lee Krasner',
#  'Nina Li (actress)',
#  'Jean Erdman',
#  'Otto I, Margrave of Brandenburg',
#  'Mary Archer',
#  'Mavis Leno',
#  'Lauri Peters',
#  'Marcheline Bertrand',
#  'Isabella, Countess of Gloucester',
#  'Isabella of Angoulême',
#  'Lupe Vélez',
#  'Lyle Lovett',
#  'Daniel Moder',
#  'Herta Haas',
#  'Jovanka Broz',
#  'Courtney Love',
#  'Kyra Sedgwick',
#  'Jill Krementz',
#  'Protima Bedi',
#  'Nikki Bedi',
#  'Peter Gordon (composer)',
#  'Bertha Benz',
#  'Kim McLagan',
#  'Camille Grammer',
#  'Elisabeth Waldheim',
#  'Fathia Nkrumah',
#  'Hilary Bardwell',
#  'Elizabeth Jane Howard',
#  'Anna Chernenko',
#  'Grete Keilson',
#  'Stage name',
#  'Alexis Minotis',
#  'Betty Kaunda',
#  'Pamela Anderson',
#  'George W. Bush',
#  'Marina Oswald Porter',
#  'Geordie Hormel',
#  'Peter Hall (director)',
#  'Michael Laughlin',
#  'Ross Petty',
#  'Aleksandra Sokolovskaya',
#  'Natalia Sedova',
#  'Margaret Grubb',
#  'Sara Northrup Hollister',
#  'Mary Sue Hubbard',
#  'Harriet Vane',
#  'Jeanne Renault',
#  'Ermengarde of Hesbaye',
#  'Judith of Bavaria (795-843)',
#  'Maria, wife of Leo III',
#  'Elizabeth Cabot Agassiz',
#  'Tullia (daughter of Servius Tullius)',
#  'Maud Gage Baum',
#  'Lil Hardin Armstrong',
#  'Elena Gaussen',
#  'Margaret of Provence',
#  'Maria Theresa of Spain',
#  "Françoise d'Aubigné, marquise de Maintenon",
#  'Giovanni Sforza',
#  'Alfonso of Aragon (1481–1500)',
#  "Alfonso I d'Este, Duke of Ferrara",
#  'Clarice Orsini',
#  'Dit name',
#  'Owen Moore',
#  'Douglas Fairbanks',
#  'Charles \\"Buddy\\" Rogers',
#  'Emine Gülbahar Hatun',
#  'Gülşah Hatun',
#  'Sittişah Hatun',
#  'Çiçek Hatun',
#  'Julia Cameron',
#  'Isabella Rossellini',
#  'Barbara De Fina',
#  'Joe DiMaggio',
#  'Arthur Miller',
#  'Kasturba Gandhi',
#  'Maeve Gilmore',
#  'Luo Yixiu',
#  'Yang Kaihui',
#  'He Zizhen',
#  'Jiang Qing',
#  'Zipporah',
#  'Cushi',
#  'Tamie Fraser',
#  'Hannah Van Buren',
#  'William Godwin',
#  'Jill Craigie',
#  'Denis Thatcher',
#  'Ayşe Hatun (wife of Murad IV)',
#  'Safiye Sultan',
#  'Şemsiruhsar Hatun',
#  'Hatice Halime Hatun',
#  'Hüma Hatun',
#  'Mara Branković',
#  'Handan Sultan',
#  'Halime Sultan',
#  'Anna Kashfi',
#  'Movita Castaneda',
#  'Tarita Teriipaia',
#  'Gülçiçek Hatun',
#  'Kera Tamara',
#  'Emine Hatun',
#  'Samira Khashoggi',
#  'Coretta Scott King',
#  'Gustavus Adolphus of Sweden',
#  'Sergei Efron',
#  'Anne Bancroft',
#  'Corinna Schumacher',
#  'Pierre Curie',
#  'Alexander III of Russia',
#  'Kathryn Grody',
#  'Nicholas Robinson (historian)',
#  'Richeza of Lotharingia',
#  'Dobrawa of Bohemia',
#  'Oda of Haldensleben',
#  'Gruoch of Scotland',
#  'Francis II of France',
#  'Henry Stuart, Lord Darnley',
#  'James Hepburn, 4th Earl of Bothwell',
#  'Nonia Celsa',
#  'Sigismund of Luxembourg',
#  'Ruqaiya Hasan',
#  'Philip II of Spain',
#  'Chichimecacihuatzin I',
#  'Anne-Marie Martin',
#  'Betty Shabazz',
#  'Grant Tinker',
#  'Humaira Begum',
#  'Raisa Gorbachova',
#  'Patricia Arquette',
#  'Lisa Marie Presley',
#  'Joachim II Hector, Elector of Brandenburg',
#  'Ronald Reagan',
#  'Tom Cruise',
#  'Keith Urban',
#  'David Shipley',
#  'Claudia Octavia',
#  'Poppaea Sabina',
#  'Pythagoras (freedman)',
#  'Statilia Messalina',
#  'Sporus',
#  'Carol Chomsky',
#  'Sophia Hawthorne',
#  'Ian Smith (lobbyist)',
#  'Anna Larina',
#  'Amanda Palmer',
#  'Avi Lewis',
#  'Glenys Kinnock, Baroness Kinnock of Holyhead',
#  'Rita Hayworth',
#  'Paola Mori',
#  'Elizabeth Bourchier',
#  'Johanna von Puttkamer',
#  'Akile Hatun',
#  'Meylişah Hatun',
#  'Ayşe Hatun (wife of Osman II)',
#  'Nilüfer Hatun',
#  'Asporça Hatun',
#  'Theodora Kantakouzene, wife of Orhan',
#  'Eftandise Hatun',
#  'Malhun Hatun',
#  'Rabia Bala Hatun',
#  'Poppaea Sabina',
#  'Margaret Hanmer',
#  'Constance Lloyd',
#  'Beatrice of Hohenstaufen',
#  'Marie of Brabant, Holy Roman Empress',
#  'Javier Bardem',
#  'Tommy Lee',
#  'Kid Rock',
#  'Rick Salomon',
#  'Eslanda Robeson',
#  'Judy Huxtable',
#  'Shera Danese',
#  'Annita van Iersel',
#  'Antistia',
#  'Aemilia Scaura',
#  'Mucia Tertia',
#  'Julia (daughter of Julius Caesar)',
#  'Cornelia Metella',
#  'George Hearst',
#  'Charles, Prince of Wales',
#  'Olga Khokhlova',
#  'Jacqueline Roque',
#  'Khieu Ponnary',
#  'Prince Daniel, Duke of Västergötland',
#  'Marie Skłodowska-Curie',
#  'Margaret Trudeau',
#  'Britt Ekland',
#  'Miranda, Countess of Stockton',
#  'Lynne Frederick',
#  'Alice Dunbar',
#  'Katherine Woodville (actress)',
#  '1988 in literature',
#  'Lydia Davis',
#  'Siri Hustvedt',
#  'Isabella of Hainaut',
#  'Ingeborg of Denmark, Queen of France',
#  'Agnes of Merania',
#  'Dave Barbour',
#  'Brad Dexter',
#  'Dewey Martin (actor)',
#  'Virginia Heinlein',
#  'Barbara Kwiatkowska-Lass',
#  'Sharon Tate',
#  'Emmanuelle Seigner',
#  'Frances H. Flaherty',
#  'Pat Nixon',
#  'Jane Wyman',
#  'Nancy Reagan',
#  'Elizabeth Avellán',
#  'Leslie Parrish',
#  'Kathleen Scott',
#  'Danielle Spencer (Australian singer)',
#  'Brenda Davies',
#  'Laura Borden',
#  'Elizabeth Bottomley',
#  'Carol Shaw (video game designer)',
#  'Garson Kanin',
#  'Marian Stamp Dawkins',
#  'Lalla Ward',
#  'Regina Peruggi',
#  'Donna Hanover',
#  'Judith Giuliani',
#  'Lina Heydrich',
#  'Pattie Menzies',
#  'Anna Murdoch Mann',
#  'Wendi Deng Murdoch',
#  'Jerry Hall',
#  'Née',
#  'Sonia Gandhi',
#  'Khadijeh Saqafi',
#  'Dane Witherspoon',
#  'Sean Penn',
#  'Penny Marshall',
#  'Akiko Yano',
#  'Anne Neville',
#  'Berengaria of Navarre',
#  'Fanny Van de Grift',
#  'Doris Pawn',
#  'Alice Terry',
#  'Joseph Reitman',
#  'Martha Bernays',
#  'Diane Cilento',
#  'Sofia Coppola',
#  'Amy Irving',
#  'Kate Capshaw',
#  'Veronica Lario',
#  'Tabitha King',
#  'Hürrem Sultan',
#  'Mahidevran Gülbahar',
#  'Gülfem Hatun',
#  'Betsy Brantley',
#  'Jules Asner',
#  'Freddie Prinze, Jr.',
#  'Cher',
#  'Mary Bono',
#  'François-Henri Pinault',
#  'Elisabeth Pepys',
#  'Sherry Turkle',
#  'Suzanne Massie',
#  'Rhonda Roland Shearer',
#  'Candice Clark',
#  'Ernest Augustus, Elector of Brunswick-Lüneburg',
#  'Nurbanu Sultan',
#  'Maria Christierna of Habsburg',
#  'Anna Jagiellon',
#  'Julia Domna',
#  'Chiang Kai-shek',
#  'Ted Hughes',
#  'Robert John \\"Mutt\\" Lange',
#  'Marianne Wiggins',
#  'Padma Lakshmi',
#  'Alexandra Bellow',
#  'Matilda of Boulogne',
#  'Hak Ja Han',
#  'Lucy Barker',
#  'Sajida Talfah',
#  'Samira Shahbandar',
#  'Jesse James (customizer)',
#  'Brady Smith (actor)',
#  'Gisela of Hungary',
#  'Vivienne Haigh-Wood',
#  'Valerie Eliot',
#  'Miriam Stoppard',
#  'Sabrina Guinness',
#  'Alice, Lady More',
#  'Vipsania Agrippina',
#  'Julia the Elder',
#  'Alice Hathaway Lee Roosevelt',
#  '107th New York State Legislature',
#  'Edith Roosevelt',
#  'Stephen King',
#  'Pentti Arajärvi',
#  'Laurie S. Fulton',
#  'Sylvia Plath',
#  'Nena von Schlebrügge',
#  'Rosemary Woodruff Leary',
#  'Otto II, Holy Roman Emperor',
#  'Nene (person)',
#  'Yodo-Dono',
#  'Lady Tsukiyama',
#  'Lois Irene Kimsey Marshall',
#  'Zanele Dlamini Mbeki',
#  'Mimi Rogers',
#  'Nicole Kidman',
#  'Katie Holmes',
#  'Julia Grant',
#  'Giuditta Rissone',
#  'María Mercader',
#  'Vera Nabokov',
#  'Joan D. Vinge',
#  'Albia Dominica',
#  'Drahomíra',
#  'Colonel James Blood',
#  'Leonard Woolf',
#  'Louise Lasser',
#  'Soon-Yi Previn',
#  'Lyudmila Putina',
#  "Anne Hathaway (Shakespeare's wife)",
#  'Lisa Kreuzer',
#  'Ronee Blakley',
#  'Marta Sahagún de Fox',
#  'Laurence Olivier',
#  'Florence Harding',
#  'Syrie Maugham',
#  'Lena Herzog',
#  'Catherine Blake',
#  'Erika Mann',
#  'Ida Saxton McKinley',
#  'Helen Herron Taft',
#  'Zoé Laurier',
#  'Anna Harrison',
#  'Millicent Hearst',
#  'Carol Grace',
#  'Ellen Axson Wilson',
#  'Edith Wilson',
#  'Maria Luise von Quistorp',
#  'Elizabeth Raleigh',
#  'Nelson Mandela',
#  'Joan Vollmer',
#  'Hester Pitt, Countess of Chatham',
#  'Ermengarde de Beaumont',
#  'Matilda of Flanders',
#  'Catherine Gladstone',
#  'Bobby Brown',
#  'Suha Arafat',
#  'Clotilde',
#  'John McVie',
#  'Zoë Ball',
#  'Jeff Koons',
#  'Julie Andrews',
#  'Freddie Ross Hancock',
#  'Vanessa Kensington',
#  'Marion Freisler',
#  'Wilhelmine of Prussia, Queen of the Netherlands',
#  "Henrietta d'Oultremont",
#  'Rebecca Moesta',
#  'Olivia A. Davidson',
#  'Margaret Murray Washington',
#  'Queen Anne of Romania',
#  'Zizi Lambrino',
#  'Helen of Greece and Denmark',
#  'Magda Lupescu',
#  'Charlie Sheen',
#  'Marie of Romania',
#  'Maria Antonescu',
#  'Linda Lee Cadwell',
#  'Sofia Sigizmundovna Dzerzhinskaya',
#  'Yuri Bogolyubsky',
#  'David Soslan',
#  'Sophie de Condorcet',
#  'Samantha Juste',
#  'Trina Dolenz',
#  'Danielle Mitterrand',
#  'Elizabeth of Bohemia (1292–1330)',
#  'Beatrice of Bourbon (1320-1383)',
#  'Heidi Klum',
#  'Djamila Bouhired',
#  'Katherine Anna Kang',
#  'Emilie Schindler',
#  'Mirta Diaz-Balart',
#  'Elizabeth of Luxembourg',
#  'Elizabeth of Carinthia',
#  'Benjamin Millepied',
#  'Antony Armstrong-Jones, 1st Earl of Snowdon',
#  'Désirée Clary',
#  'Josephine of Leuchtenberg',
#  'Viveca Lindfors',
#  'Doe Avedon',
#  'Margaret of Bohemia, Queen of Hungary',
#  'Elizabeth of Bosnia',
#  'Mary Boies',
#  'Elisabeth of Nuremberg',
#  'Joanna of Bavaria',
#  'Sophia of Bavaria',
#  'Beatrix of Świdnica',
#  'Margaret II, Countess of Holland',
#  'Mary of Hungary',
#  'Barbara of Celje',
#  'Blanche of Valois',
#  'Anna of Bavaria',
#  'Anna von Schweidnitz',
#  'Elizabeth of Pomerania',
#  'Assia Noris',
#  'Ingrid Bergman',
#  'Enrica Antonioni',
#  'Constance, Duchess of Wodzisław',
#  'Matilda of Brandenburg, Duchess of Poland',
#  'Judith of Hungary',
#  'Emnilda of Lusatia',
#  'Oda of Meissen',
#  'Margaret of Baden',
#  'Anna of Saxony (d. 1512)',
#  'Jessi Colter',
#  'Judy Agnew',
#  'Mary of Burgundy',
#  'Anne of Brittany',
#  'Bianca Maria Sforza',
#  'Elizabeth of Austria (1436–1505)',
#  'Henry VIII of England',
#  'Elisabeth of Bavaria-Landshut',
#  'Maria of Spain',
#  'Tutte Lemkow',
#  'Frank Bunker Gilbreth, Sr.',
#  'Adelheid of Vohburg',
#  'Beatrice I, Countess of Burgundy',
#  'Rima Horton',
#  'Beatrice of Provence',
#  'Margaret of Burgundy, Queen of Sicily',
#  'Elisabeth of Austria (1526-1545)',
#  'Barbara Radziwiłł',
#  'Catherine of Austria (1533–1572)',
#  'Bernadette Chirac',
#  'Edith Baumann (politician)',
#  'Margot Honecker',
#  'Brad Pitt',
#  'Justin Theroux',
#  'Louise of the Netherlands',
#  'Gala Dalí',
#  'Gytha Thorkelsdóttir',
#  'Edyth Swannesha',
#  'Ealdgyth, daughter of Earl Ælfgar',
#  'Eleanor \\"Sis\\" Daley',
#  'Caroline of Brunswick',
#  'Æthelred the Unready',
#  'Cnut the Great',
#  'Edith of Wessex',
#  'Edith Ogden Harrison',
#  'Jay McMullen (Chicago journalist)',
#  'Sheila Hancock',
#  'Świętosława',
#  'Sigrid the Haughty',
#  'Gunhild of Wenden',
#  'Lucretia Garfield',
#  'Gertrude of Comburg',
#  'Gertrude of Sulzbach',
#  'Richenza of Northeim',
#  'Cuman',
#  'Ælfgifu of Northampton',
#  'Emma of Normandy',
#  'Rogneda of Polotsk',
#  'Malfrida',
#  'Anna Porphyrogenita',
#  'Otto I, Holy Roman Emperor',
#  'Gertrud von Hindenburg',
#  'Elizabeth Schuyler Hamilton',
#  'Edmond Hamilton',
#  'Anne Parillaud',
#  'Maïwenn',
#  'Milla Jovovich',
#  'Virginie Silla',
#  'Loki Schmidt',
#  'Hannelore Kohl',
#  'Roberto Rossellini',
#  'Emma Jung',
#  'Charlotte of Mecklenburg-Strelitz',
#  'Diane Lane',
#  'Sophie Marceau',
#  'Josephine Dillon',
#  'Carole Lombard',
#  'Sylvia Ashley',
#  'Menen Asfaw',
#  'Anne Byrne (actress)',
#  'Lisa Hoffman',
#  'Benji Madden',
#  'Joan Mondale',
#  'Sinéad de Valera',
#  'Amanda Demme',
#  'Ingegerd Olofsdotter of Sweden',
#  'Olof Skötkonung',
#  'Ewelina Hańska',
#  'Rzewuski family',
#  'Poppa of Bayeux',
#  'Gisela of France',
#  'Conrad Hilton, Jr.',
#  'Michael Wilding (actor)',
#  'Mike Todd',
#  'Eddie Fisher (singer)',
#  'Richard Burton',
#  'John Warner',
#  'Larry Fortensky',
#  'Gyrid Olafsdottir',
#  'Tove of the Obotrites',
#  'Clyde Klotz',
#  'Olof Skötkonung',
#  'Barbara Zápolya',
#  'Bona Sforza',
#  'Jadwiga of Poland',
#  'Anne of Cilli',
#  'Elisabeth of Pilica',
#  'Sophia of Halshany',
#  'Rainier III, Prince of Monaco',
#  'Nina Petrovna Khrushcheva',
#  'Chris Martin',
#  'Peggy Guggenheim',
#  'Dorothea Tanning',
#  "John Jay O'Connor",
#  'Muriel Humphrey Brown',
#  'Demo Castellon',
#  'Kathryn M. Drennan',
#  'Molly Kazan',
#  'Barbara Loden',
#  'Frances Kazan',
#  'Sargent Shriver',
#  'Natalie Talmadge',
#  'Phil Bronstein',
#  'Dario Franchitti',
#  'Mickey Rooney',
#  'Artie Shaw',
#  'Frank Sinatra',
#  'Bruce Wagner',
#  'Felicia Montealegre',
#  'Ros Kelly',
#  'Adelaide of Saxe-Meiningen',
#  'Odaenathus',
#  'Ulpia Severina',
#  'Henry Brewster Stanton',
#  'Dina Eastwood',
#  'Olga Scheinpflugová',
#  'Rita Wilson',
#  'Lady Caroline Lamb',
#  'Fulk, King of Jerusalem',
#  'Carol McCain',
#  'Cindy McCain',
#  'Johann Christoph Gottsched',
#  'Polly Platt',
#  'Vanessa Redgrave',
#  'Jane Wenham (actress)',
#  'Anouk Aimée',
#  'Alexis Denisof',
#  'Leah Rabin',
#  'Evelyn Keyes',
#  'Enrica Soma',
#  'Susan Wallace',
#  'Shelley Winters',
#  'Melissa Mathison',
#  'Calista Flockhart',
#  'Henry II, King of France',
#  'Małgorzata Braunek',
#  'Peter the Great',
#  'Peter III of Russia',
#  ...]

# %% [markdown]
# The relation column does not need any kind of cleaning or modification. However, the person1 and person2 columns of all three dataframes need extensive cleaning. There is a lot of trivial information in these columns. A lot of the rows have years mentioned, while others have titles like "Queen of England", "Earl of Lovalace", "Duchess of Prussia" to name a few.
#
# ###  I have two methods to clean these columns with maximum retention of information.
#
# 1. The first method will split a column into multiple columns based on the presence whitespaces.
#
# * This will turn a column that looks like "**Prince William Harry, the third**" into **"Prince", "William", "Harry,", "the", "third"**.
#
#
# 2. The second method will split a column into multiple columns based on the presence of commas.
#
# * This will turn a column that looks like "**Prince William Harry, the third**" into "**Prince William Harry**", and "**the third**".

# %%
def split_column(data, how = ' ', exp = True, col_name = 'Name'):
    
    # splitting a column in our dataframe based on whitespace, comma, or any other specification
    data_split = data.str.split(how, expand = exp)
    
    if how == ',':
        data_split.rename(columns={0:col_name}, inplace = True)
    else:
        data_split.rename(columns={0:"First Name", 1:"Middle Name", 2:"Last Name"}, inplace = True)
    
    return data_split

# %%
spouse_person2 = split_column(spouse_data['person2'], ',')

# %%
spouse_person2.iloc[1:10]
# Out:
#                      Name     1     2
# 1  Pauline Bush (actress)  None  None
# 2              Irma Raush  None  None
# 3      Larisa Tarkovskaya  None  None
# 4            Mileva Marić  None  None
# 5          Elsa Löwenthal  None  None
# 6                  Roxana  None  None
# 7             Stateira II  None  None
# 8            Parysatis II  None  None
# 9                   Kreka  None  None

# %%
# taking a look at row 15 after splitting our column
spouse_person2.iloc[[15]]
# Out:
#                  Name                      1     2
# 15  William King-Noel   1st Earl of Lovelace  None

# %%
# taking a look at row 59 after splitting our column
spouse_person2.iloc[[59]]
# Out:
#                                           Name     1     2
# 59  Beatrice D'Este (Queen Consort of Hungary)  None  None

# %% [markdown]
# Initially, the first approach seems promising but in some cases like row 59 we end up with useless information inside parenthesis. If we decide to go with this approach we will have a lot of trivial information in our training data.

# %%
spouse_person2_ws = split_column(spouse_data['person2'], ' ')

# %%
spouse_person2_ws.iloc[1:10]
# Out:
#   First Name  Middle Name  Last Name     3     4     5     6     7     8  \
# 1    Pauline         Bush  (actress)  None  None  None  None  None  None
# 2       Irma        Raush       None  None  None  None  None  None  None
# 3     Larisa  Tarkovskaya       None  None  None  None  None  None  None
# 4     Mileva        Marić       None  None  None  None  None  None  None
# 5       Elsa    Löwenthal       None  None  None  None  None  None  None
# 6     Roxana         None       None  None  None  None  None  None  None
# 7   Stateira           II       None  None  None  None  None  None  None
# 8  Parysatis           II       None  None  None  None  None  None  None
# 9      Kreka         None       None  None  None  None  None  None  None
#
#       9    10    11    12    13
# 1  None  None  None  None  None
# 2  None  None  None  None  None
# 3  None  None  None  None  None
# 4  None  None  None  None  None
# 5  None  None  None  None  None
# 6  None  None  None  None  None
# 7  None  None  None  None  None
# 8  None  None  None  None  None
# 9  None  None  None  None  None

# %%
# taking a look at row 15 after splitting our column
spouse_person2_ws.iloc[[15]]
# Out:
#    First Name Middle Name Last Name     3   4         5     6     7     8  \
# 15    William  King-Noel,       1st  Earl  of  Lovelace  None  None  None
#
#        9    10    11    12    13
# 15  None  None  None  None  None

# %%
# taking a look at row 59 after splitting our column
spouse_person2_ws.iloc[[59]]
# Out:
#    First Name Middle Name Last Name        3   4         5     6     7     8  \
# 59   Beatrice      D'Este    (Queen  Consort  of  Hungary)  None  None  None
#
#        9    10    11    12    13
# 59  None  None  None  None  None

# %% [markdown]
# However, if we assume that a name consists of atmost 2-3 words then we can simply use the second approach and split our column in first, middle and last names. Later we can combine these and drop the rest of the colums. A big risk of this approach is our assumption because the dataset is too large to actually check all entries manually.
#
# Even after this, some anomalities exits. While going through the data an entry **'1983 Major League Baseball season'** was found. The presence of such an entry in the person2 column of spouse data renders the entire row useless. At this point, it is unknown as to how many entries are similar to this, because we are only interested in names of people and relations between them.

# %% [markdown]
# ## Using regular expressions to clean the data.
#
# I ran some experiments on the data to clean it using the regex module of python. In short these regular expressions have helped us to remove **initials, non alphanumeric characters, anything within parenthesis, roman numerals, and multiple spaces** from our data. At last we are converting our data into lower case alphabets.
#
# Detailed experiments can be found below in this notebook.

# %%
def clean_column(text):
    
    # removing initials from names
    text = re.sub(r"[A-Z]\.", r" ", text)
    # removing non alphanumeric characters
    text = re.sub(r"([-;;.,!?<=>])", r" ", text)
    
    # removing anything within parenthesis for e.g (1943-46), (actress)
    text = re.sub(r'([/-;;.,"!&?<=>\\])', r"", text)
    # removing roman numerals like I, II, V, IX etc.
    text = re.sub(r"\b(?=[MDCLXVIΙ])M{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})([IΙ]X|[IΙ]V|V?[IΙ]{0,3})\b\.?", r" ", text)
    # removing multiple spaces
    text = re.sub(" +", " ", text)
    
    # convert the text into lower case
    text = text.lower()
    # removing any blank spaces from the beginning or ending of text
    text = text.strip()
    
    return text

# %% [markdown]
# ### Removing any information present within parenthesis.
#
# If we use the below regular expression we can convert **"Allan Dwan spouse Pauline Bush(Actress)"** to **'allan dwan spouse pauline bush'**.

# %%
text = "Allan Dwan spouse Pauline Bush(Actress)"
text = re.sub(r"\([^()]*\)", r"", text)
text.strip()
text.lower()
# Out:
# 'allan dwan spouse pauline bush'

# %%
text = 'Beatrice of Castile(1242–1303)'
text = re.sub(r"\([^()]*\)", r"", text)
text.strip()
text.lower()
# Out:
# 'beatrice of castile'

# %% [markdown]
# ### Removing roman numerls from our data.
#
# Roman numerical system: **I = 1, V = 5, X = 10, L = 50, C = 100, D = 500, M = 1,000**. Using a combination of these alphabets we can represent any number in the roman numerical system. For e.g. 4 is represented by IV. The used regular expression is robust as it will just remove the roman numerls and not the corresponding English alphabets like I, V, X, L, C, D, and M.
#
# If we use the below regular expression we can convert **"Alan TuringX XVII I IV IX M"** to **'Alan TuringX'**.

# %%
text = "Alan TuringX XVII I IV IX M"
text = re.sub(r"\b(?=[MDCLXVIΙ])M{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})([IΙ]X|[IΙ]V|V?[IΙ]{0,3})\b\.?", r"", text)
text.strip()
# Out:
# 'Alan TuringX'

# %% [markdown]
# ### Removing initials from a name.
#
# If we use the below regular expression we can remove any initial from a name as long as the initial is followed by a dot. We can convert **'A. D. van Vogt'** to **'van vogt'**.

# %%
text = 'A. D. van vogt'
text = re.sub(r'[A-Z]\.', r'', text)
text.strip()
# Out:
# 'van vogt'

# %% [markdown]
# ### Removing special character from a name
#
# Special characters include - '**/**', '**-**', '**;**', '**.**', '**"**', '**!**', '**&**', '**?**', '**<**', '**>**', and '**\**'. If we use the below regular expression we can remove any of the above mentioned special characters from a name. We can convert **'Charles// \\"Buddy\\" &R;o:gers'** to **'Charles Buddy Rogers'**.

# %%
text = 'Charles// \\"Buddy\\" &R;o:gers'
text = re.sub(r'([/-;;.,"!&?<=>\\])', r"", text)
text.strip()
# Out:
# 'Charles Buddy Rogers'

# %%
text = 'duke of prussia spouse anna marie of //brunswick" - /lüneburg'
text = re.sub(r'([/-;;.,"!?<=>])', r"", text)
text = re.sub(" +", " ", text)
text.strip()
# Out:
# 'duke of prussia spouse anna marie of brunswick - lüneburg'

# %% [markdown]
# ### Removing trivial information under names from our data.
#
# While taking a look at our dataset we came across some trivial entries under the names of people. Some of these entries were '**1993 in film**', '**1997 in film**', and '**1983 Major League Baseball season**'. To handle these kinds of entries we will use a custom function to check if a name starts with a non alphabet and we will note down the index values of such entries for removing them later.

# %%
def check_name(data, col_name='person2'):
    
    # initializing an empty list 
    idx = []
    
    # iterating over the values in a specific column
    for i, val in enumerate(data[col_name]):
        # checking if the value starts with an english alphabet or not
        if val[0].isalpha():
            continue
        # appending the index of the value that does not start with an alphabet
        else:
            idx.append(i)
            
    return idx

# %% [markdown]
# ### Splitting and merging columns to remove trivial information from data.

# %%
child_split_1 = split_column(child_data['person1'], ',', col_name = 'person1')
child_split_1.head()
# Out:
#             person1     1     2
# 0   Abraham Lincoln  None  None
# 1   Abraham Lincoln  None  None
# 2   Abraham Lincoln  None  None
# 3   Abraham Lincoln  None  None
# 4  Alfred Hitchcock  None  None

# %%
child_split_2 = split_column(child_data['person2'], ',', col_name = 'person2')
child_split_2.head()
# Out:
#                    person2     1     2
# 0      Robert Todd Lincoln  None  None
# 1     Edward Baker Lincoln  None  None
# 2  William Wallace Lincoln  None  None
# 3              Tad Lincoln  None  None
# 4       Patricia Hitchcock  None  None

# %%
#child_data['merged'] = child_split_1['person1'].astype(str) + ' ' + child_data['relation'].astype(str) + ' ' + child_split_2['person2'].astype(str)
#child_data.head()

# %%
child_data = merge_column(child_split_2, child_data, child_split_1, col1='person2', col2='relation', col3='person1')
child_data.head()
# Out:
#             person1 relation                  person2  \
# 0   Abraham Lincoln    child      Robert Todd Lincoln
# 1   Abraham Lincoln    child     Edward Baker Lincoln
# 2   Abraham Lincoln    child  William Wallace Lincoln
# 3   Abraham Lincoln    child              Tad Lincoln
# 4  Alfred Hitchcock    child       Patricia Hitchcock
#
#                                 relation triplet
# 0      Robert Todd Lincoln child Abraham Lincoln
# 1     Edward Baker Lincoln child Abraham Lincoln
# 2  William Wallace Lincoln child Abraham Lincoln
# 3              Tad Lincoln child Abraham Lincoln
# 4      Patricia Hitchcock child Alfred Hitchcock

# %%
parent_split_1 = split_column(parent_data['person1'], ',', col_name = 'person1')
parent_split_2 = split_column(parent_data['person2'], ',', col_name = 'person2')

# %%
parent_data = merge_column(parent_split_2, parent_data, parent_split_1, col1='person2', col2='relation', col3='person1')
parent_data.head()
# Out:
#                person1 relation               person2  \
# 0     Andrei Tarkovsky   parent      Arseny Tarkovsky
# 1  Alexander the Great   parent  Philip II of Macedon
# 2  Alexander the Great   parent              Olympias
# 3               Attila   parent               Mundzuk
# 4           Alp Arslan   parent           Chaghri Beg
#
#                                   relation triplet
# 0         Arseny Tarkovsky parent Andrei Tarkovsky
# 1  Philip II of Macedon parent Alexander the Great
# 2              Olympias parent Alexander the Great
# 3                            Mundzuk parent Attila
# 4                    Chaghri Beg parent Alp Arslan

# %%
parent_split_1.head()
# Out:
#                person1     1
# 0     Andrei Tarkovsky  None
# 1  Alexander the Great  None
# 2  Alexander the Great  None
# 3               Attila  None
# 4           Alp Arslan  None

# %%
spouse_split_1 = split_column(spouse_data['person1'], ',', col_name = 'person1')
spouse_split_2 = split_column(spouse_data['person2'], ',', col_name = 'person2')

# %%
spouse_data = merge_column(spouse_split_1, spouse_data, spouse_split_2)
spouse_data.head()
# Out:
#             person1 relation                 person2  \
# 0   Abraham Lincoln   spouse       Mary Todd Lincoln
# 1        Allan Dwan   spouse  Pauline Bush (actress)
# 2  Andrei Tarkovsky   spouse              Irma Raush
# 3  Andrei Tarkovsky   spouse      Larisa Tarkovskaya
# 4   Albert Einstein   spouse            Mileva Marić
#
#                              relation triplet
# 0    Abraham Lincoln spouse Mary Todd Lincoln
# 1    Allan Dwan spouse Pauline Bush (actress)
# 2          Andrei Tarkovsky spouse Irma Raush
# 3  Andrei Tarkovsky spouse Larisa Tarkovskaya
# 4         Albert Einstein spouse Mileva Marić

# %%
spouse_data.drop_duplicates(subset=['person1'], keep='first', inplace=True, ignore_index = True)

# %%
check(spouse_data)
# Out:
# The data has 30223 rows and 4 colums.
# There are 30223 unique values in Person1 column and 28255 unique values in Person2 column.
# Number of empty rows in the respective columns are person1: 0, relation: 0, person2: 0

# %%
spouse_data.drop_duplicates(subset=['person2'], keep='first', inplace=True, ignore_index = True)

# %%
check(spouse_data)
# Out:
# The data has 28255 rows and 4 colums.
# There are 28255 unique values in Person1 column and 28255 unique values in Person2 column.
# Number of empty rows in the respective columns are person1: 0, relation: 0, person2: 0

# %%
spouse_data.head()
# Out:
#                person1 relation                 person2  \
# 0      Abraham Lincoln   spouse       Mary Todd Lincoln
# 1           Allan Dwan   spouse  Pauline Bush (actress)
# 2     Andrei Tarkovsky   spouse              Irma Raush
# 3      Albert Einstein   spouse            Mileva Marić
# 4  Alexander the Great   spouse                  Roxana
#
#                            relation triplet
# 0  Abraham Lincoln spouse Mary Todd Lincoln
# 1  Allan Dwan spouse Pauline Bush (actress)
# 2        Andrei Tarkovsky spouse Irma Raush
# 3       Albert Einstein spouse Mileva Marić
# 4         Alexander the Great spouse Roxana

# %%
spouse_data.tail()
# Out:
#                                    person1 relation  \
# 28250  John Graham (Australian politician)   spouse
# 28251                             Lisa Joy   spouse
# 28252               Shahriar Sayeed Husain   spouse
# 28253       Hazrat Khanoum Nosrat Saltaneh   spouse
# 28254                      Chantal Hochuli   spouse
#
#                                           person2  \
# 28250                            Jenny McAllister
# 28251                              Jonathan Nolan
# 28252                        Farah Mahbub (judge)
# 28253                                   Ed-Dowleh
# 28254  Prince Ernst August of Hanover (born 1954)
#
#                                         relation triplet
# 28250  John Graham (Australian politician) spouse Jen...
# 28251                     Lisa Joy spouse Jonathan Nolan
# 28252  Shahriar Sayeed Husain spouse Farah Mahbub (ju...
# 28253    Hazrat Khanoum Nosrat Saltaneh spouse Ed-Dowleh
# 28254  Chantal Hochuli spouse Prince Ernst August of ...

# %%
text = '1993 in film'
text[0].isdigit()
# Out:
# True

# %%
test_data = {"person1": ['Ajay', 'Anu', 'Abhinav', 'Tommy'], "relation": ['siblings', 'siblings', 'siblings', 'siblings'], "person2": ['1993 in game', 'Rashi', 'Vanshi', '#psy']}
df = pd.DataFrame(data=test_data)

# %%
df
# Out:
#    person1  relation       person2
# 0     Ajay  siblings  1993 in game
# 1      Anu  siblings         Rashi
# 2  Abhinav  siblings        Vanshi
# 3    Tommy  siblings          #psy

# %%
x, _ = df.shape
x
# Out:
# 4

# %%
idx = []
for i, val in enumerate(df['person2']):
    if val[0].isalpha():
        continue
    else:
        idx.append(i)

# %%
idx
# Out:
# [0, 3]

# %%
def drop_rows(data, labels, axis=0, inplace=True):
    
    # dropping specific rows from our dataframe using a list of indexes
    data.drop(labels=labels, axis=axis, inplace=inplace)
    # reset the index of our dataframe
    data.reset_index(inplace=inplace)
    
    return data

# %%
idx = check_name(spouse_data)

# %%
idx
# Out:
# [100,
#  927,
#  1048,
#  1840,
#  1880,
#  2106,
#  2134,
#  2989,
#  3309,
#  3400,
#  3453,
#  3550,
#  3631,
#  4474,
#  5146,
#  5434,
#  5926,
#  5937,
#  6671,
#  6805,
#  7027,
#  7623,
#  7688,
#  7756,
#  7937,
#  8467,
#  8789,
#  8839,
#  9423,
#  10045,
#  10149,
#  10163,
#  11209,
#  12157,
#  12383,
#  12963,
#  16826,
#  19086,
#  20718,
#  21219,
#  22015,
#  24948,
#  27349,
#  27882]

# %%
spouse_data.iloc[[2134]]
# Out:
#           person1 relation       person2                 relation triplet
# 2134  Peter Fonda   spouse  1974 in film  Peter Fonda spouse 1974 in film

# %%
len(idx)
# Out:
# 44

# %%
test = []
for val in idx:
    test.append(spouse_data.iloc[[val]])

# %%
test
# Out:
# [        person1 relation                            person2  \
#  100  Bob Costas   spouse  1983 Major League Baseball season
#
#                                        relation triplet
#  100  Bob Costas spouse 1983 Major League Baseball s...  ,
#               person1 relation              person2  \
#  927  Whoopi Goldberg   spouse  66th Academy Awards
#
#                                 relation triplet
#  927  Whoopi Goldberg spouse 66th Academy Awards  ,
#            person1 relation              person2  \
#  1048  Bette Davis   spouse  11th Academy Awards
#
#                              relation triplet
#  1048  Bette Davis spouse 11th Academy Awards  ,
#             person1 relation      person2                 relation triplet
#  1840  Phil Collins   spouse  1999 (song)  Phil Collins spouse 1999 (song),
#               person1 relation             person2  \
#  1880  Dwayne Johnson   spouse  1997 Slammy Awards
#
#                                relation triplet
#  1880  Dwayne Johnson spouse 1997 Slammy Awards  ,
#            person1 relation             person2  \
#  2106  Lisa Kudrow   spouse  1995 in television
#
#                             relation triplet
#  2106  Lisa Kudrow spouse 1995 in television  ,
#            person1 relation       person2                 relation triplet
#  2134  Peter Fonda   spouse  1974 in film  Peter Fonda spouse 1974 in film,
#            person1 relation                 person2  \
#  2989  Peter Brock   spouse  1969 Hardie-Ferodo 500
#
#                                 relation triplet
#  2989  Peter Brock spouse 1969 Hardie-Ferodo 500  ,
#               person1 relation       person2  \
#  3309  Frankie Avalon   spouse  1963 in film
#
#                          relation triplet
#  3309  Frankie Avalon spouse 1963 in film  ,
#                person1 relation                  person2  \
#  3400  Ralf Schumacher   spouse  2001 Formula One season
#
#                                      relation triplet
#  3400  Ralf Schumacher spouse 2001 Formula One season  ,
#             person1 relation                     person2  \
#  3453  Theo Epstein   spouse  2007 Boston Red Sox season
#
#                                      relation triplet
#  3453  Theo Epstein spouse 2007 Boston Red Sox season  ,
#           person1 relation       person2                relation triplet
#  3550  Pat Morita   spouse  1967 in film  Pat Morita spouse 1967 in film,
#                        person1 relation                 person2  \
#  3631  William Grover-Williams   spouse  1929 Grand Prix season
#
#                                         relation triplet
#  3631  William Grover-Williams spouse 1929 Grand Prix...  ,
#              person1 relation       person2                   relation triplet
#  4474  Peter Strauss   spouse  1973 in film  Peter Strauss spouse 1973 in film,
#             person1 relation       person2                  relation triplet
#  5146  Jack Palance   spouse  1968 in film  Jack Palance spouse 1968 in film,
#                  person1 relation       person2  \
#  5434  Michael Badalucco   spouse  1996 in film
#
#                             relation triplet
#  5434  Michael Badalucco spouse 1996 in film  ,
#           person1 relation       person2                relation triplet
#  5926  Una Merkel   spouse  1932 in film  Una Merkel spouse 1932 in film,
#             person1 relation       person2                  relation triplet
#  5937  Cyd Charisse   spouse  1947 in film  Cyd Charisse spouse 1947 in film,
#                person1 relation       person2  \
#  6671  Sally Kellerman   spouse  1970 in film
#
#                           relation triplet
#  6671  Sally Kellerman spouse 1970 in film  ,
#             person1 relation       person2                  relation triplet
#  6805  Joanna Kerns   spouse  1976 in film  Joanna Kerns spouse 1976 in film,
#               person1 relation                        person2  \
#  7027  Jimmie Johnson   spouse  2004 NASCAR Nextel Cup Series
#
#                                         relation triplet
#  7027  Jimmie Johnson spouse 2004 NASCAR Nextel Cup S...  ,
#                person1 relation       person2  \
#  7623  Robert Cummings   spouse  1933 in film
#
#                           relation triplet
#  7623  Robert Cummings spouse 1933 in film  ,
#               person1 relation             person2  \
#  7688  Gonçalves Dias   spouse  1856 in literature
#
#                                relation triplet
#  7688  Gonçalves Dias spouse 1856 in literature  ,
#             person1 relation                     person2  \
#  7756  Tracy Morgan   spouse  61st Primetime Emmy Awards
#
#                                      relation triplet
#  7756  Tracy Morgan spouse 61st Primetime Emmy Awards  ,
#         person1 relation       person2              relation triplet
#  7937  Mo'Nique   spouse  2001 in film  Mo'Nique spouse 2001 in film,
#           person1 relation       person2                relation triplet
#  8467  Mel Ferrer   spouse  1944 in film  Mel Ferrer spouse 1944 in film,
#                     person1 relation       person2  \
#  8789  Don Davis (composer)   spouse  1986 in film
#
#                                relation triplet
#  8789  Don Davis (composer) spouse 1986 in film  ,
#            person1 relation       person2                 relation triplet
#  8839  Lola Falana   spouse  1975 in film  Lola Falana spouse 1975 in film,
#            person1 relation          person2  \
#  9423  Ava Vincent   spouse  18th AVN Awards
#
#                          relation triplet
#  9423  Ava Vincent spouse 18th AVN Awards  ,
#           person1 relation       person2               relation triplet
#  10045  Lynn Bari   spouse  1939 in film  Lynn Bari spouse 1939 in film,
#                person1 relation       person2  \
#  10149  Patrick Bergin   spouse  1992 in film
#
#                           relation triplet
#  10149  Patrick Bergin spouse 1992 in film  ,
#              person1 relation       person2                  relation triplet
#  10163  Anne Francis   spouse  1952 in film  Anne Francis spouse 1952 in film,
#            person1 relation                                            person2  \
#  11209  Judy Greer   spouse  2010–2011 United States network television sch...
#
#                                          relation triplet
#  11209  Judy Greer spouse 2010–2011 United States netw...  ,
#                                          person1 relation  \
#  12157  Dan Reeves (American football executive)   spouse
#
#                              person2  \
#  12157  1971 Los Angeles Rams season
#
#                                          relation triplet
#  12157  Dan Reeves (American football executive) spous...  ,
#                person1 relation       person2  \
#  12383  Tiffany Shepis   spouse  2010 in film
#
#                           relation triplet
#  12383  Tiffany Shepis spouse 2010 in film  ,
#             person1 relation        person2                  relation triplet
#  12963  Tony Hoffer   spouse  2005 in music  Tony Hoffer spouse 2005 in music,
#              person1 relation       person2                  relation triplet
#  16826  Allan Edwall   spouse  1965 in film  Allan Edwall spouse 1965 in film,
#             person1 relation             person2  \
#  19086  Jeff Gordon   spouse  1994 Brickyard 400
#
#                              relation triplet
#  19086  Jeff Gordon spouse 1994 Brickyard 400  ,
#         person1 relation                  person2  \
#  20718  J. Cole   spouse  2015 BET Hip Hop Awards
#
#                               relation triplet
#  20718  J. Cole spouse 2015 BET Hip Hop Awards  ,
#           person1 relation       person2               relation triplet
#  21219  Lew Davis   spouse  1948 in film  Lew Davis spouse 1948 in film,
#            person1 relation                   person2  \
#  22015  Chad Duell   spouse  39th Daytime Emmy Awards
#
#                                   relation triplet
#  22015  Chad Duell spouse 39th Daytime Emmy Awards  ,
#             person1 relation        person2                  relation triplet
#  24948  Henri Betti   spouse  1949 in music  Henri Betti spouse 1949 in music,
#                       person1 relation       person2  \
#  27349  Annie Macaulay-Idibia   spouse  2face Idibia
#
#                                  relation triplet
#  27349  Annie Macaulay-Idibia spouse 2face Idibia  ,
#                person1 relation                   person2  \
#  27882  Norma Connolly   spouse  12th Daytime Emmy Awards
#
#                                       relation triplet
#  27882  Norma Connolly spouse 12th Daytime Emmy Awards  ]

# %%
spouse_data.head()
# Out:
#                person1 relation                 person2  \
# 0      Abraham Lincoln   spouse       Mary Todd Lincoln
# 1           Allan Dwan   spouse  Pauline Bush (actress)
# 2     Andrei Tarkovsky   spouse              Irma Raush
# 3      Albert Einstein   spouse            Mileva Marić
# 4  Alexander the Great   spouse                  Roxana
#
#                            relation triplet
# 0  Abraham Lincoln spouse Mary Todd Lincoln
# 1  Allan Dwan spouse Pauline Bush (actress)
# 2        Andrei Tarkovsky spouse Irma Raush
# 3       Albert Einstein spouse Mileva Marić
# 4         Alexander the Great spouse Roxana

# %%
spouse_data.shape
# Out:
# (28255, 4)

# %%
spouse_data = drop_rows(spouse_data, idx)

# %%
spouse_data.shape
# Out:
# (28211, 5)

# %%
idx = check_name(spouse_data, col_name='person1')

# %%
idx
# Out:
# [74, 27032]

# %%
spouse_data.iloc[[74]]
# Out:
#     index       person1 relation         person2  \
# 74     74  `Abdu'l-Bahá   spouse  Munírih Khánum
#
#                       relation triplet
# 74  `Abdu'l-Bahá spouse Munírih Khánum

# %%
spouse_data.iloc[[27032]]
# Out:
#        index                person1 relation        person2  \
# 27032  27074  (George) Clyde Fisher   spouse  Te Ata Fisher
#
#                                  relation triplet
# 27032  (George) Clyde Fisher spouse Te Ata Fisher

# %%
spouse_data.drop(['index'], axis=1, inplace=True)

# %%
spouse_data
# Out:
#                                    person1 relation  \
# 0                          Abraham Lincoln   spouse
# 1                               Allan Dwan   spouse
# 2                         Andrei Tarkovsky   spouse
# 3                          Albert Einstein   spouse
# 4                      Alexander the Great   spouse
# ...                                    ...      ...
# 28206  John Graham (Australian politician)   spouse
# 28207                             Lisa Joy   spouse
# 28208               Shahriar Sayeed Husain   spouse
# 28209       Hazrat Khanoum Nosrat Saltaneh   spouse
# 28210                      Chantal Hochuli   spouse
#
#                                           person2  \
# 0                               Mary Todd Lincoln
# 1                          Pauline Bush (actress)
# 2                                      Irma Raush
# 3                                    Mileva Marić
# 4                                          Roxana
# ...                                           ...
# 28206                            Jenny McAllister
# 28207                              Jonathan Nolan
# 28208                        Farah Mahbub (judge)
# 28209                                   Ed-Dowleh
# 28210  Prince Ernst August of Hanover (born 1954)
#
#                                         relation triplet
# 0               Abraham Lincoln spouse Mary Todd Lincoln
# 1               Allan Dwan spouse Pauline Bush (actress)
# 2                     Andrei Tarkovsky spouse Irma Raush
# 3                    Albert Einstein spouse Mileva Marić
# 4                      Alexander the Great spouse Roxana
# ...                                                  ...
# 28206  John Graham (Australian politician) spouse Jen...
# 28207                     Lisa Joy spouse Jonathan Nolan
# 28208  Shahriar Sayeed Husain spouse Farah Mahbub (ju...
# 28209    Hazrat Khanoum Nosrat Saltaneh spouse Ed-Dowleh
# 28210  Chantal Hochuli spouse Prince Ernst August of ...
#
# [28211 rows x 4 columns]

# %%
idx = check_name(parent_data)

# %%
idx
# Out:
# [9289, 9307]

# %%
parent_data.iloc[[9289]]
# Out:
#               person1 relation         person2  \
# 9289  Sharaf al-Dawla   parent  'Adud al-Dawla
#
#                            relation triplet
# 9289  'Adud al-Dawla parent Sharaf al-Dawla

# %%
parent_data.iloc[[9307]]
# Out:
#               person1 relation         person2  \
# 9307  Samsam al-Dawla   parent  'Adud al-Dawla
#
#                            relation triplet
# 9307  'Adud al-Dawla parent Samsam al-Dawla

# %%
idx = check_name(parent_data, col_name='person1')

# %%
idx
# Out:
# [120, 121, 3634, 10311, 10312, 21983, 25945, 27264]

# %%
parent_data.iloc[[120]]
# Out:
#           person1 relation      person2                 relation triplet
# 120  `Abdu'l-Bahá   parent  Bahá’u’lláh  Bahá’u’lláh parent `Abdu'l-Bahá

# %%
parent_data.iloc[[121]]
# Out:
#           person1 relation        person2                   relation triplet
# 121  `Abdu'l-Bahá   parent  Ásíyih Khánum  Ásíyih Khánum parent `Abdu'l-Bahá

# %%
parent_data.iloc[[3634]]
# Out:
#            person1 relation       person2                  relation triplet
# 3634  'Abd al-Ilah   parent  Ali of Hejaz  Ali of Hejaz parent 'Abd al-Ilah

# %%
parent_data.iloc[[10311]]
# Out:
#               person1 relation        person2  \
# 10311  'Adud al-Dawla   parent  Rukn al-Dawla
#
#                           relation triplet
# 10311  Rukn al-Dawla parent 'Adud al-Dawla

# %%
parent_data.iloc[[10312]]
# Out:
#               person1 relation     person2                  relation triplet
# 10312  'Adud al-Dawla   parent  Firuzanids  Firuzanids parent 'Adud al-Dawla

# %%
parent_data.iloc[[21983]]
# Out:
#                                    person1 relation  \
# 21983  'Abd ar-Rahman ibn Muhammad al-Amin   parent
#
#                           person2  \
# 21983  Muhammad al-Amin al-Kanemi
#
#                                         relation triplet
# 21983  Muhammad al-Amin al-Kanemi parent 'Abd ar-Rahm...

# %%
parent_data.iloc[[25945]]
# Out:
#                         person1 relation       person2  \
# 25945  2014 Isla Vista killings   parent  Peter Rodger
#
#                                    relation triplet
# 25945  Peter Rodger parent 2014 Isla Vista killings

# %%
parent_data.iloc[[27264]]
# Out:
#           person1 relation              person2  \
# 27264  28th Ruler   parent  Yik'in Chan K'awiil
#
#                             relation triplet
# 27264  Yik'in Chan K'awiil parent 28th Ruler

# %%
idx = check_name(child_data)

# %%
idx
# Out:
# [8904, 9504, 10849]

# %%
child_data.iloc[[8904]]
# Out:
#            person1 relation                      person2  \
# 8904  Suresh Nanda    child  1999 Delhi hit-and-run case
#
#                                     relation triplet
# 8904  1999 Delhi hit-and-run case child Suresh Nanda

# %%
child_data.iloc[[9504]]
# Out:
#                  person1 relation     person2  \
# 9504  Roberto Micheletti    child  3 (number)
#
#                          relation triplet
# 9504  3 (number) child Roberto Micheletti

# %%
child_data.iloc[[10849]]
# Out:
#            person1 relation person2     relation triplet
# 10849  Jack Dellal    child       £  £ child Jack Dellal

# %%
idx = check_name(child_data, col_name='person1')

# %%
idx
# Out:
# []
